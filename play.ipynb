# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl

df = pd.read_excel("c:\\Users\\ahmad\\Downloads\\RFM-Clustering\\data\\raw\\final_file.xlsx")

dd = pd.read_csv("c:\\Users\\ahmad\\Downloads\\RFM-Clustering\\data\\processed\\rfm_processed.csv")

ff = pd.read_csv("c:\\Users\\ahmad\\Downloads\\RFM-Clustering\\data\\processed\\x_processed.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Buyer           3921 non-null   int64
#  1   Recency         3921 non-null   float64
#  2   First_Purchase  3921 non-null   float64
#  3   Frequency       3921 non-null   int64
#  4   Monetary        3921 non-null   float64
#  5   Minimum         3921 non-null   float64
#  6   Maximum         3921 non-null   float64
#  7   Mean            3921 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 245.2 KB

# %%
dd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Buyer           3921 non-null   int64
#  1   Recency         3921 non-null   float64
#  2   First_Purchase  3921 non-null   float64
#  3   Frequency       3921 non-null   int64
#  4   Monetary        3921 non-null   float64
#  5   Minimum         3921 non-null   float64
#  6   Maximum         3921 non-null   float64
#  7   Mean            3921 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 245.2 KB

# %%
ff.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    3921 non-null   float64
#  1   Frequency  3921 non-null   float64
#  2   Monetary   3921 non-null   float64
# dtypes: float64(3)
# memory usage: 92.0 KB
